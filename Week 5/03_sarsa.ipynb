# %% [markdown]
# # 03 — SARSA (On-Policy TD Control)
# **Week 5 | Model-Free Learning**
#
# SARSA learns Q(s,a) — action values — using the **actual next action taken**:
#
# $$Q(s,a) \leftarrow Q(s,a) + \alpha \Big[ R + \gamma \; Q(s', \underbrace{a'}_{\text{action actually taken}}) - Q(s,a) \Big]$$
#
# The name comes from the quintuple: **(S, A, R, S', A')**
# On-policy: the policy being improved is the same one being followed.

# %%
try:
    import gymnasium as gym
except ImportError:
    import subprocess, sys; subprocess.check_call([sys.executable,'-m','pip','install','gymnasium','-q']); import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)

env = gym.make('Taxi-v3')
n_s = env.observation_space.n; n_a = env.action_space.n
print(f"Taxi-v3: {n_s} states, {n_a} actions")

# %% [markdown]
# ## 1. SARSA Implementation

# %%
def sarsa(env, n_episodes=10_000, alpha=0.1, gamma=0.99,
          eps_start=1.0, eps_end=0.01, eps_decay=0.999):
    Q = np.zeros((n_s, n_a))
    eps = eps_start
    returns_per_ep = []
    steps_per_ep = []

    def eps_greedy(s):
        if np.random.rand() < eps: return env.action_space.sample()
        return np.argmax(Q[s])

    for ep in range(n_episodes):
        s, _ = env.reset()
        a = eps_greedy(s)
        ep_return = 0.0
        steps = 0
        done = False

        while not done:
            ns, r, term, trunc, _ = env.step(a)
            done = term or trunc
            na = eps_greedy(ns)

            # SARSA update — uses next action a' that was CHOSEN (on-policy)
            Q[s,a] += alpha * (r + gamma * Q[ns,na] * (not done) - Q[s,a])

            s, a = ns, na
            ep_return += r
            steps += 1

        eps = max(eps_end, eps * eps_decay)
        returns_per_ep.append(ep_return)
        steps_per_ep.append(steps)

    return Q, returns_per_ep, steps_per_ep

print("Training SARSA on Taxi-v3...")
Q_sarsa, returns_sarsa, steps_sarsa = sarsa(env, n_episodes=15_000)
print(f"Done. Final ε ≈ 0.01")

# %%
window = 300
fig, axes = plt.subplots(1, 2, figsize=(12, 3.5))
for ax, data, label, color in [
    (axes[0], returns_sarsa, 'Avg Return', 'steelblue'),
    (axes[1], steps_sarsa,   'Steps/Episode', 'darkorange')]:
    rolling = np.convolve(data, np.ones(window)/window, mode='valid')
    ax.plot(rolling, color=color, linewidth=1.5)
    ax.set_xlabel('Episode'); ax.set_ylabel(label)
    ax.set_title(f'SARSA — {label} (rolling {window})')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 2. Visualise the Q-Table

# %%
action_names = ['South','North','East','West','Pickup','Dropoff']

# Show Q-values for first 20 states
fig, ax = plt.subplots(figsize=(10, 5))
im = ax.imshow(Q_sarsa[:30, :], cmap='RdYlGn', aspect='auto')
plt.colorbar(im, ax=ax)
ax.set_xticks(range(n_a)); ax.set_xticklabels(action_names, rotation=20, ha='right')
ax.set_ylabel('State (first 30)'); ax.set_title('Q-Table (SARSA) — first 30 states')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3. Evaluate the Greedy Policy

# %%
def evaluate(env, Q, n_episodes=500):
    rewards = []
    for _ in range(n_episodes):
        s, _ = env.reset(); ep_r = 0; done = False
        for _ in range(200):
            a = np.argmax(Q[s])
            s, r, term, trunc, _ = env.step(a)
            ep_r += r; done = term or trunc
            if done: break
        rewards.append(ep_r)
    return np.mean(rewards), np.std(rewards)

mean_r, std_r = evaluate(env, Q_sarsa)
print(f"SARSA greedy policy: mean return = {mean_r:.2f} ± {std_r:.2f}")
print(f"(Random policy baseline is around -200)")

# %% [markdown]
# ## ✅ Exercises
# 1. Change α from 0.1 to 0.5. Does SARSA learn faster or does it become unstable?
# 2. Use a **decaying ε** schedule (start=1.0, end=0.01, linear decay). Compare to exponential decay.
# 3. **Challenge**: implement **SARSA(λ)** with eligibility traces. Does it learn faster than SARSA(0)?

# %% [markdown]
# ## Q1

# %% [markdown]
# Faster initially, but less stable. α=0.5 causes Q-values to update more aggressively, so learning progresses faster in early episodes. However, the return curve remains noisier throughout — large updates prevent the Q-values from settling smoothly.

# %%
Q_sarsa_05, returns_05, _ = sarsa(env, n_episodes=15_000, alpha=0.5)

window = 300
plt.figure(figsize=(8, 3.5))
plt.plot(np.convolve(returns_sarsa, np.ones(window)/window, mode='valid'), color='steelblue', label='α=0.1')
plt.plot(np.convolve(returns_05,    np.ones(window)/window, mode='valid'), color='tomato',    label='α=0.5')
plt.xlabel('Episode'); plt.ylabel('Avg Return')
plt.title('SARSA — α=0.1 vs α=0.5')
plt.legend(); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Q2

# %%
def sarsa_linear_decay(env, n_episodes=15_000, alpha=0.1, gamma=0.99,
                        eps_start=1.0, eps_end=0.01):
    Q = np.zeros((n_s, n_a))
    returns_per_ep = []

    for ep in range(n_episodes):
        eps = max(eps_end, eps_start - ep * (eps_start - eps_end) / n_episodes)
        s, _ = env.reset()
        a = np.random.randint(n_a) if np.random.rand() < eps else np.argmax(Q[s])
        ep_return = 0.0; done = False

        while not done:
            ns, r, term, trunc, _ = env.step(a)
            done = term or trunc
            na = np.random.randint(n_a) if np.random.rand() < eps else np.argmax(Q[ns])
            Q[s, a] += alpha * (r + gamma * Q[ns, na] * (not done) - Q[s, a])
            s, a = ns, na
            ep_return += r

        returns_per_ep.append(ep_return)
    return Q, returns_per_ep

Q_linear, returns_linear = sarsa_linear_decay(env)

window = 300
plt.figure(figsize=(8, 3.5))
plt.plot(np.convolve(returns_sarsa, np.ones(window)/window, mode='valid'), color='steelblue', label='Exponential decay')
plt.plot(np.convolve(returns_linear, np.ones(window)/window, mode='valid'), color='tomato',   label='Linear decay')
plt.xlabel('Episode'); plt.ylabel('Avg Return')
plt.title('SARSA — Exponential vs Linear ε Decay')
plt.legend(); plt.tight_layout(); plt.show()

mean_linear, std_linear = evaluate(env, Q_linear)
print(f"Linear decay  — mean return: {mean_linear:.2f} ± {std_linear:.2f}")
print(f"Exp decay     — mean return: {mean_r:.2f} ± {std_r:.2f}")

# %% [markdown]
# Linear decay reduces ε at a constant rate, so exploration drops quickly in early episodes and the agent exploits sooner. Exponential decay keeps ε higher for longer, allowing more exploration before committing to a policy. Which performs better depends on the environment — on Taxi-v3, exponential decay typically yields a more stable final policy since the state space is large and requires sustained exploration.

# %% [markdown]
# ##  Q3

# %%
def sarsa_lambda(env, n_episodes=15_000, alpha=0.1, gamma=0.99,
                 lam=0.8, eps_start=1.0, eps_end=0.01, eps_decay=0.999):
    Q   = np.zeros((n_s, n_a))
    eps = eps_start
    returns_per_ep = []

    def eps_greedy(s):
        return env.action_space.sample() if np.random.rand() < eps else np.argmax(Q[s])

    for ep in range(n_episodes):
        s, _ = env.reset()
        a    = eps_greedy(s)
        e    = np.zeros((n_s, n_a))   # eligibility traces
        ep_return = 0.0; done = False

        while not done:
            ns, r, term, trunc, _ = env.step(a)
            done = term or trunc
            na   = eps_greedy(ns)

            td_error  = r + gamma * Q[ns, na] * (not done) - Q[s, a]
            e[s, a]  += 1.0                     # accumulate trace
            Q        += alpha * td_error * e    # update all (s,a) weighted by trace
            e        *= gamma * lam             # decay all traces

            s, a = ns, na
            ep_return += r

        eps = max(eps_end, eps * eps_decay)
        returns_per_ep.append(ep_return)
    return Q, returns_per_ep

Q_lam, returns_lam = sarsa_lambda(env, lam=0.8)

window = 300
plt.figure(figsize=(8, 3.5))
plt.plot(np.convolve(returns_sarsa, np.ones(window)/window, mode='valid'), color='steelblue', label='SARSA(0)')
plt.plot(np.convolve(returns_lam,   np.ones(window)/window, mode='valid'), color='seagreen',  label='SARSA(λ=0.8)')
plt.xlabel('Episode'); plt.ylabel('Avg Return')
plt.title('SARSA(0) vs SARSA(λ=0.8) on Taxi-v3')
plt.legend(); plt.tight_layout(); plt.show()

mean_lam, std_lam = evaluate(env, Q_lam)
print(f"SARSA(0)      mean return: {mean_r:.2f} ± {std_r:.2f}")
print(f"SARSA(λ=0.8) mean return: {mean_lam:.2f} ± {std_lam:.2f}")

# %% [markdown]
# Yes, SARSA(λ) learns faster than SARSA(0). Eligibility traces propagate the TD error backward to all recently visited state-action pairs in the same step, rather than updating only the current pair. This speeds up credit assignment across longer trajectories, which is particularly beneficial on Taxi-v3 where successful episodes require many sequential correct actions.
