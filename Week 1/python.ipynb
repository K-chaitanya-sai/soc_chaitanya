# %%
7**4
# Out:
# 2401

# %%
s = "Hi there Sam!"
s.split()
# Out:
# ['Hi', 'there', 'Sam!']

# %%
planet = "Earth"
diameter = 12742
print("The diameter of {oo} is {bb} kilometers.".format(oo=planet,bb=diameter))
# Out:
# The diameter of Earth is 12742 kilometers.

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
lst[3][1][2]
# Out:
# ['hello']

# %%
p="user@domain.com"
def domainGet(x):
    l=x.split('@')
    return l[1]
y=domainGet(p)
y
# Out:
# 'domain.com'

# %%
e='Is there a dog here?'
def findDog(t):
    k=t.split()
    for i in k:
        if i=='dog':
            return True
    return false     
int = findDog(e)
int
# Out:
# True

# %%
e='This dog runs faster than the other dog dude!'
def countDog(t):
    x=0
    k=t.split()
    for i in k:
        if i=='dog':
            x+=1
    return x     
int = countDog(e)
int
# Out:
# 2

# %%
seq = ['soup', 'dog', 'salad', 'cat', 'great']

result = list(filter(lambda word: word.startswith('s'), seq))

print(result)
# Out:
# ['soup', 'salad']

# %%
def caught_speeding(speed, is_birthday):
    if is_birthday:
        speed -= 5

    if speed <= 60:
        return "No Ticket"
    elif speed <= 80:
        return "Small Ticket"
    else:
        return "Big Ticket"

# %%
print(caught_speeding(81, True))

print(caught_speeding(81, False))

print(caught_speeding(60, False))

print(caught_speeding(65, True))

print(caught_speeding(75, False))

print(caught_speeding(90, True))
# Out:
# Small Ticket
# Big Ticket
# No Ticket
# No Ticket
# Small Ticket
# Big Ticket
